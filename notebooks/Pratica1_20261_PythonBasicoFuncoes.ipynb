# %% [markdown]
# # Atividade Pratica 1 (Sem.2026.1) – Python Básico aplicado à Construção Civil
# Responder a questão incluindo narrativa, enunciado completo, fluxograma (descrição), pseudocódigo e solução comentada. A atividade deverá ser enviada o código via plataforma do Teams e apresentada na próxima aula ao professor. A entrega deve ser feita usando o modelo latex, anexando no Teams o pdf, link do overleaf com acesso ao professor e o código latex.

# %% [markdown]
# ![image.png](Figuras/pratica1_20261/image_cell1.png)

# %% [markdown]
# ![image.png](Figuras/pratica1_20261/image_cell2.png)

# %% [markdown]
# ![image.png](Figuras/pratica1_20261/image_cell3.png)

# %% [markdown]
# ![image.png](Figuras/pratica1_20261/image_cell4.png)

# %% [markdown]
# ![image.png](Figuras/pratica1_20261/image_cell5.png)

# %% [markdown]
# ![image.png](Figuras/pratica1_20261/image_cell6.png)

# %% [markdown]
# ![image.png](Figuras/pratica1_20261/image_cell7.png)
